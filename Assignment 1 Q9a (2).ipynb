# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\Games\Bhag Milkha Bhag 2013 Hindi MC DVDScr Xvid AC3 IcTv\Desktop\CSV\Q9_a.csv")

# %%
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
df.describe()
# Out:
#           Index      speed        dist
# count  50.00000  50.000000   50.000000
# mean   25.50000  15.400000   42.980000
# std    14.57738   5.287644   25.769377
# min     1.00000   4.000000    2.000000
# 25%    13.25000  12.000000   26.000000
# 50%    25.50000  15.000000   36.000000
# 75%    37.75000  19.000000   56.000000
# max    50.00000  25.000000  120.000000

# %%
df1=df[['speed','dist']]

# %%
df1
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
df1.skew()
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df1.kurtosis()
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurtosis()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df1.speed)
# Out:
# (array([2., 3., 4., 6., 8., 5., 7., 8., 1., 6.]),
#  array([ 4. ,  6.1,  8.2, 10.3, 12.4, 14.5, 16.6, 18.7, 20.8, 22.9, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1.dist)
# Out:
# (array([ 4.,  8., 14.,  6.,  7.,  4.,  3.,  3.,  0.,  1.]),
#  array([  2. ,  13.8,  25.6,  37.4,  49.2,  61. ,  72.8,  84.6,  96.4,
#         108.2, 120. ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns

# %%
sns.distplot(df1.dist)
